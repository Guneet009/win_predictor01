# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import warnings
from sklearn.preprocessing import OrdinalEncoder
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Reading data

# %%
df = pd.read_csv("ipl_Data//matches.csv")

# %%
df.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %% [markdown]
# ### Dropping uncessary data

# %%
df.drop(columns=['umpire2','umpire1','method','target_overs','super_over','target_overs','result_margin','result','player_of_match','match_type','id'],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#     season        city        date  \
# 0  2007/08   Bangalore  2008-04-18
# 1  2007/08  Chandigarh  2008-04-19
# 2  2007/08       Delhi  2008-04-19
# 3  2007/08      Mumbai  2008-04-20
# 4  2007/08     Kolkata  2008-04-20
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner  target_runs
# 0        Kolkata Knight Riders        223.0
# 1          Chennai Super Kings        241.0
# 2             Delhi Daredevils        130.0
# 3  Royal Challengers Bangalore        166.0
# 4        Kolkata Knight Riders        111.0

# %% [markdown]
# ### Analyzing redundant data and removing it

# %%
df['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
df["team2"].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
df['winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Daredevils',
#        'Royal Challengers Bangalore', 'Rajasthan Royals',
#        'Kings XI Punjab', 'Deccan Chargers', 'Mumbai Indians',
#        'Pune Warriors', 'Kochi Tuskers Kerala', nan,
#        'Sunrisers Hyderabad', 'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
df['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Mumbai Indians', 'Deccan Chargers',
#        'Kings XI Punjab', 'Kolkata Knight Riders', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Gujarat Titans', 'Lucknow Super Giants',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
team_mapping = {'Royal Challengers Bengaluru':'Royal Challengers Bangalore','Deccan Chargers':'Sunrisers Hyderabad','Kings XI Punjab':'Punjab Kings','Delhi Daredevils':'Delhi Capitals','Gujarat Lions':'Gujarat Titans'}

# %%
team_mapping
# Out:
# {'Royal Challengers Bengaluru': 'Royal Challengers Bangalore',
#  'Deccan Chargers': 'Sunrisers Hyderabad',
#  'Kings XI Punjab': 'Punjab Kings',
#  'Delhi Daredevils': 'Delhi Capitals',
#  'Gujarat Lions': 'Gujarat Titans'}

# %%
cols_to_update = ['team1','team2','winner','toss_winner']

# %%
cols_to_update
# Out:
# ['team1', 'team2', 'winner', 'toss_winner']

# %% [markdown]
# ### function correct the name

# %%
def replace_duplicates(df,cols,arr:dict):
    for col in cols:
        df[col] = df[col].replace(arr)

# %%
replace_duplicates(df,cols_to_update,team_mapping)

# %%
df.shape
# Out:
# (1006, 10)

# %%
df['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Mumbai Indians', 'Sunrisers Hyderabad',
#        'Punjab Kings', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'Gujarat Titans', 'Lucknow Super Giants'], dtype=object)

# %% [markdown]
# ### Removing discontnued teams

# %%
df = df[~df['winner'].str.contains('Rising Pune Supergiant|Rising Pune Supergiants|Kochi Tuskers Kerala|Pune Warriors', na=False)]

# %% [markdown]
# ### Removing rows with no result

# %%
df[df['winner'].isna()]
# Out:
#     season       city        date  \
# 485   2015  Bangalore  2015-04-29
# 511   2015  Bangalore  2015-05-17
# 744   2019  Bengaluru  2019-04-30
# 994   2023    Lucknow  2023-05-03
#
#                                                  venue  \
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 744                              M.Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                team2  \
# 485  Royal Challengers Bangalore     Rajasthan Royals
# 511  Royal Challengers Bangalore       Delhi Capitals
# 744  Royal Challengers Bangalore     Rajasthan Royals
# 994         Lucknow Super Giants  Chennai Super Kings
#
#                      toss_winner toss_decision winner  target_runs
# 485             Rajasthan Royals         field    NaN          NaN
# 511  Royal Challengers Bangalore         field    NaN        188.0
# 744             Rajasthan Royals         field    NaN         63.0
# 994          Chennai Super Kings         field    NaN          NaN

# %%
df = df.dropna(subset=['winner'])

# %%
df[df['winner'].isna()]
# Out:
# Empty DataFrame
# Columns: [season, city, date, venue, team1, team2, toss_winner, toss_decision, winner, target_runs]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 0 to 1094
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1002 non-null   object
#  1   city           951 non-null    object
#  2   date           1002 non-null   object
#  3   venue          1002 non-null   object
#  4   team1          1002 non-null   object
#  5   team2          1002 non-null   object
#  6   toss_winner    1002 non-null   object
#  7   toss_decision  1002 non-null   object
#  8   winner         1002 non-null   object
#  9   target_runs    1002 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 86.1+ KB

# %%
df.drop(columns=['venue'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     season        city        date                        team1  \
# 0  2007/08   Bangalore  2008-04-18  Royal Challengers Bangalore
# 1  2007/08  Chandigarh  2008-04-19                 Punjab Kings
# 2  2007/08       Delhi  2008-04-19               Delhi Capitals
# 3  2007/08      Mumbai  2008-04-20               Mumbai Indians
# 4  2007/08     Kolkata  2008-04-20        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4          Sunrisers Hyderabad          Sunrisers Hyderabad           bat
#
#                         winner  target_runs
# 0        Kolkata Knight Riders        223.0
# 1          Chennai Super Kings        241.0
# 2               Delhi Capitals        130.0
# 3  Royal Challengers Bangalore        166.0
# 4        Kolkata Knight Riders        111.0

# %% [markdown]
# ### Checking null values

# %%
df[df['city'].isna()]
# Out:
#       season city        date                        team1  \
# 399     2014  NaN  2014-04-17               Delhi Capitals
# 402     2014  NaN  2014-04-19  Royal Challengers Bangalore
# 403     2014  NaN  2014-04-19        Kolkata Knight Riders
# 404     2014  NaN  2014-04-20             Rajasthan Royals
# 406     2014  NaN  2014-04-22                 Punjab Kings
# 407     2014  NaN  2014-04-23             Rajasthan Royals
# 408     2014  NaN  2014-04-24  Royal Challengers Bangalore
# 409     2014  NaN  2014-04-25          Sunrisers Hyderabad
# 410     2014  NaN  2014-04-25          Chennai Super Kings
# 413     2014  NaN  2014-04-27               Delhi Capitals
# 414     2014  NaN  2014-04-27          Sunrisers Hyderabad
# 415     2014  NaN  2014-04-28                 Punjab Kings
# 417     2014  NaN  2014-04-30               Mumbai Indians
# 757  2020/21  NaN  2020-09-20               Delhi Capitals
# 758  2020/21  NaN  2020-09-21  Royal Challengers Bangalore
# 759  2020/21  NaN  2020-09-22             Rajasthan Royals
# 761  2020/21  NaN  2020-09-24                 Punjab Kings
# 762  2020/21  NaN  2020-09-25               Delhi Capitals
# 764  2020/21  NaN  2020-09-27                 Punjab Kings
# 765  2020/21  NaN  2020-09-28  Royal Challengers Bangalore
# 767  2020/21  NaN  2020-09-30        Kolkata Knight Riders
# 769  2020/21  NaN  2020-10-02          Sunrisers Hyderabad
# 771  2020/21  NaN  2020-10-03               Delhi Capitals
# 772  2020/21  NaN  2020-10-04                 Punjab Kings
# 773  2020/21  NaN  2020-10-04               Mumbai Indians
# 774  2020/21  NaN  2020-10-05               Delhi Capitals
# 777  2020/21  NaN  2020-10-08          Sunrisers Hyderabad
# 778  2020/21  NaN  2020-10-09               Delhi Capitals
# 780  2020/21  NaN  2020-10-10  Royal Challengers Bangalore
# 781  2020/21  NaN  2020-10-11          Sunrisers Hyderabad
# 783  2020/21  NaN  2020-10-12  Royal Challengers Bangalore
# 784  2020/21  NaN  2020-10-13          Chennai Super Kings
# 785  2020/21  NaN  2020-10-14               Delhi Capitals
# 786  2020/21  NaN  2020-10-15  Royal Challengers Bangalore
# 788  2020/21  NaN  2020-10-17          Chennai Super Kings
# 789  2020/21  NaN  2020-10-17             Rajasthan Royals
# 791  2020/21  NaN  2020-10-18               Mumbai Indians
# 793  2020/21  NaN  2020-10-20               Delhi Capitals
# 795  2020/21  NaN  2020-10-22             Rajasthan Royals
# 796  2020/21  NaN  2020-10-23          Chennai Super Kings
# 798  2020/21  NaN  2020-10-24                 Punjab Kings
# 800  2020/21  NaN  2020-10-25  Royal Challengers Bangalore
# 801  2020/21  NaN  2020-10-26        Kolkata Knight Riders
# 802  2020/21  NaN  2020-10-27          Sunrisers Hyderabad
# 804  2020/21  NaN  2020-10-29        Kolkata Knight Riders
# 806  2020/21  NaN  2020-10-31  Royal Challengers Bangalore
# 807  2020/21  NaN  2020-10-31               Delhi Capitals
# 809  2020/21  NaN  2020-11-01        Kolkata Knight Riders
# 811  2020/21  NaN  2020-11-03               Mumbai Indians
# 812  2020/21  NaN  2020-11-05               Mumbai Indians
# 815  2020/21  NaN  2020-11-10               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 399  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 402               Mumbai Indians  Royal Challengers Bangalore         field
# 403               Delhi Capitals        Kolkata Knight Riders           bat
# 404                 Punjab Kings                 Punjab Kings         field
# 406          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 407          Chennai Super Kings             Rajasthan Royals         field
# 408        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 409               Delhi Capitals          Sunrisers Hyderabad           bat
# 410               Mumbai Indians               Mumbai Indians           bat
# 413               Mumbai Indians               Mumbai Indians           bat
# 414          Chennai Super Kings          Sunrisers Hyderabad           bat
# 415  Royal Challengers Bangalore                 Punjab Kings         field
# 417          Sunrisers Hyderabad               Mumbai Indians         field
# 757                 Punjab Kings                 Punjab Kings         field
# 758          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 759          Chennai Super Kings          Chennai Super Kings         field
# 761  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 762          Chennai Super Kings          Chennai Super Kings         field
# 764             Rajasthan Royals             Rajasthan Royals         field
# 765               Mumbai Indians               Mumbai Indians         field
# 767             Rajasthan Royals             Rajasthan Royals         field
# 769          Chennai Super Kings          Sunrisers Hyderabad           bat
# 771        Kolkata Knight Riders        Kolkata Knight Riders         field
# 772          Chennai Super Kings                 Punjab Kings           bat
# 773          Sunrisers Hyderabad               Mumbai Indians           bat
# 774  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 777                 Punjab Kings          Sunrisers Hyderabad           bat
# 778             Rajasthan Royals             Rajasthan Royals         field
# 780          Chennai Super Kings  Royal Challengers Bangalore           bat
# 781             Rajasthan Royals          Sunrisers Hyderabad           bat
# 783        Kolkata Knight Riders  Royal Challengers Bangalore           bat
# 784          Sunrisers Hyderabad          Chennai Super Kings           bat
# 785             Rajasthan Royals               Delhi Capitals           bat
# 786                 Punjab Kings  Royal Challengers Bangalore           bat
# 788               Delhi Capitals          Chennai Super Kings           bat
# 789  Royal Challengers Bangalore             Rajasthan Royals           bat
# 791                 Punjab Kings               Mumbai Indians           bat
# 793                 Punjab Kings               Delhi Capitals           bat
# 795          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 796               Mumbai Indians               Mumbai Indians         field
# 798          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 800          Chennai Super Kings  Royal Challengers Bangalore           bat
# 801                 Punjab Kings                 Punjab Kings         field
# 802               Delhi Capitals               Delhi Capitals         field
# 804          Chennai Super Kings          Chennai Super Kings         field
# 806          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 807               Mumbai Indians               Mumbai Indians         field
# 809             Rajasthan Royals             Rajasthan Royals         field
# 811          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 812               Delhi Capitals               Delhi Capitals         field
# 815               Mumbai Indians               Delhi Capitals           bat
#
#                           winner  target_runs
# 399  Royal Challengers Bangalore        146.0
# 402  Royal Challengers Bangalore        116.0
# 403               Delhi Capitals        167.0
# 404                 Punjab Kings        192.0
# 406                 Punjab Kings        194.0
# 407          Chennai Super Kings        141.0
# 408        Kolkata Knight Riders        151.0
# 409          Sunrisers Hyderabad        185.0
# 410          Chennai Super Kings        142.0
# 413               Delhi Capitals        126.0
# 414          Chennai Super Kings        146.0
# 415                 Punjab Kings        125.0
# 417          Sunrisers Hyderabad        173.0
# 757               Delhi Capitals        158.0
# 758  Royal Challengers Bangalore        164.0
# 759             Rajasthan Royals        217.0
# 761                 Punjab Kings        207.0
# 762               Delhi Capitals        176.0
# 764             Rajasthan Royals        224.0
# 765  Royal Challengers Bangalore        202.0
# 767        Kolkata Knight Riders        175.0
# 769          Sunrisers Hyderabad        165.0
# 771               Delhi Capitals        229.0
# 772          Chennai Super Kings        179.0
# 773               Mumbai Indians        209.0
# 774               Delhi Capitals        197.0
# 777          Sunrisers Hyderabad        202.0
# 778               Delhi Capitals        185.0
# 780  Royal Challengers Bangalore        170.0
# 781             Rajasthan Royals        159.0
# 783  Royal Challengers Bangalore        195.0
# 784          Chennai Super Kings        168.0
# 785               Delhi Capitals        162.0
# 786                 Punjab Kings        172.0
# 788               Delhi Capitals        180.0
# 789  Royal Challengers Bangalore        178.0
# 791                 Punjab Kings        177.0
# 793                 Punjab Kings        165.0
# 795          Sunrisers Hyderabad        155.0
# 796               Mumbai Indians        115.0
# 798                 Punjab Kings        127.0
# 800          Chennai Super Kings        146.0
# 801                 Punjab Kings        150.0
# 802          Sunrisers Hyderabad        220.0
# 804          Chennai Super Kings        173.0
# 806          Sunrisers Hyderabad        121.0
# 807               Mumbai Indians        111.0
# 809        Kolkata Knight Riders        192.0
# 811          Sunrisers Hyderabad        150.0
# 812               Mumbai Indians        201.0
# 815               Mumbai Indians        157.0

# %% [markdown]
# #### Null values are present only in city columns for 20/21 season. That competion was help in Dubai due to Covid-19

# %%
df['city'] = df['city'].fillna('Dubai')

# %%
df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Dubai',
#        'Rajkot', 'Kanpur', 'Bengaluru', 'Indore', 'Sharjah',
#        'Navi Mumbai', 'Lucknow', 'Guwahati', 'Mohali'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1002 non-null   object
#  1   city           1002 non-null   object
#  2   date           1002 non-null   object
#  3   team1          1002 non-null   object
#  4   team2          1002 non-null   object
#  5   toss_winner    1002 non-null   object
#  6   toss_decision  1002 non-null   object
#  7   winner         1002 non-null   object
#  8   target_runs    1002 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 78.3+ KB

# %% [markdown]
# ### Saving cleaned data

# %%
df.to_csv("ipl_Data//ipl_data.csv",index=False)

# %% [markdown]
# ### Encoding columns with same classes

# %%
cols_with_same_class = ['team1','team2','winner','toss_winner']

# %%
df_combined = pd.concat([df[col] for col in cols_with_same_class],axis=0)

# %%
df_combined
# Out:
# 0       Royal Challengers Bangalore
# 1                      Punjab Kings
# 2                    Delhi Capitals
# 3                    Mumbai Indians
# 4             Kolkata Knight Riders
#                    ...
# 1090                   Punjab Kings
# 1091            Sunrisers Hyderabad
# 1092               Rajasthan Royals
# 1093               Rajasthan Royals
# 1094            Sunrisers Hyderabad
# Length: 4008, dtype: object

# %%
unique_classes = pd.Series(df_combined.unique())

# %%
unique_classes
# Out:
# 0    Royal Challengers Bangalore
# 1                   Punjab Kings
# 2                 Delhi Capitals
# 3                 Mumbai Indians
# 4          Kolkata Knight Riders
# 5               Rajasthan Royals
# 6            Sunrisers Hyderabad
# 7            Chennai Super Kings
# 8                 Gujarat Titans
# 9           Lucknow Super Giants
# dtype: object

# %%
unique_classes = unique_classes.values.reshape(-1,1)

# %%
encoder = OrdinalEncoder()

# %%
encoder.fit(unique_classes)
# Out:
# OrdinalEncoder()

# %%
for col in cols_with_same_class:
    df[col+'_enc'] = encoder.transform(df[[col]])

# %%
df_encoded = df.drop(columns=['team1','team2','toss_winner','winner'],axis=1)

# %%
df_encoded['toss_winner_enc'].nunique()
# Out:
# 10

# %%
df_encoded.head()
# Out:
#     season        city        date toss_decision  target_runs  team1_enc  \
# 0  2007/08   Bangalore  2008-04-18         field        223.0        8.0
# 1  2007/08  Chandigarh  2008-04-19           bat        241.0        6.0
# 2  2007/08       Delhi  2008-04-19           bat        130.0        1.0
# 3  2007/08      Mumbai  2008-04-20           bat        166.0        5.0
# 4  2007/08     Kolkata  2008-04-20           bat        111.0        3.0
#
#    team2_enc  winner_enc  toss_winner_enc
# 0        3.0         3.0              8.0
# 1        0.0         0.0              0.0
# 2        7.0         1.0              7.0
# 3        8.0         8.0              5.0
# 4        9.0         3.0              9.0

# %% [markdown]
# ### Converting date to year month and day

# %%
df_encoded['date']=pd.to_datetime(df_encoded['date'])

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 0 to 1094
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           1002 non-null   object
#  1   city             1002 non-null   object
#  2   date             1002 non-null   datetime64[ns]
#  3   toss_decision    1002 non-null   object
#  4   target_runs      1002 non-null   float64
#  5   team1_enc        1002 non-null   float64
#  6   team2_enc        1002 non-null   float64
#  7   winner_enc       1002 non-null   float64
#  8   toss_winner_enc  1002 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 78.3+ KB

# %%
df_encoded['year'] = df_encoded['date'].dt.year
df_encoded['month'] = df_encoded['date'].dt.month
df_encoded['day'] = df_encoded['date'].dt.day

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 0 to 1094
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           1002 non-null   object
#  1   city             1002 non-null   object
#  2   date             1002 non-null   datetime64[ns]
#  3   toss_decision    1002 non-null   object
#  4   target_runs      1002 non-null   float64
#  5   team1_enc        1002 non-null   float64
#  6   team2_enc        1002 non-null   float64
#  7   winner_enc       1002 non-null   float64
#  8   toss_winner_enc  1002 non-null   float64
#  9   year             1002 non-null   int32
#  10  month            1002 non-null   int32
#  11  day              1002 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(3), object(3)
# memory usage: 90.0+ KB

# %%
df_encoded.drop(columns=['season','date'],axis=1,inplace=True)

# %%
df_encoded
# Out:
#             city toss_decision  target_runs  team1_enc  team2_enc  winner_enc  \
# 0      Bangalore         field        223.0        8.0        3.0         3.0
# 1     Chandigarh           bat        241.0        6.0        0.0         0.0
# 2          Delhi           bat        130.0        1.0        7.0         1.0
# 3         Mumbai           bat        166.0        5.0        8.0         8.0
# 4        Kolkata           bat        111.0        3.0        9.0         3.0
# ...          ...           ...          ...        ...        ...         ...
# 1090   Hyderabad           bat        215.0        6.0        9.0         9.0
# 1091   Ahmedabad           bat        160.0        9.0        3.0         3.0
# 1092   Ahmedabad         field        173.0        8.0        7.0         7.0
# 1093     Chennai         field        176.0        9.0        7.0         9.0
# 1094     Chennai           bat        114.0        9.0        3.0         3.0
#
#       toss_winner_enc  year  month  day
# 0                 8.0  2008      4   18
# 1                 0.0  2008      4   19
# 2                 7.0  2008      4   19
# 3                 5.0  2008      4   20
# 4                 9.0  2008      4   20
# ...               ...   ...    ...  ...
# 1090              6.0  2024      5   19
# 1091              9.0  2024      5   21
# 1092              7.0  2024      5   22
# 1093              7.0  2024      5   24
# 1094              9.0  2024      5   26
#
# [1002 rows x 10 columns]

# %% [markdown]
# ### Saving encoded data

# %%
df_encoded.to_csv("ipl_Data//ipl_data_enc.csv",index=False)

# %%
df_encoded = pd.read_csv("ipl_Data//ipl_data_enc.csv")

# %% [markdown]
# ### Train and Test Split for time series data

# %%
train_data = df_encoded[df_encoded['year']<2024]

# %%
train_data['year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2020, 2021, 2022, 2023])

# %%
test_data = df_encoded[df_encoded['year']>2023]

# %%
test_data['year'].value_counts()
# Out:
# year
# 2024    71
# Name: count, dtype: int64

# %%
cat_col = [col for col in df_encoded.columns if df_encoded[col].dtype=='O']
num_col = ["target_runs"]

# %%
cat_col
# Out:
# ['city', 'toss_decision']

# %%
num_col
# Out:
# ['target_runs']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
import pickle
import os

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
num_pipeline = Pipeline(
    steps=[
        ("scaler",StandardScaler())
    ]
)

# %%
cat_pipeline = Pipeline(
    steps=[
        ("ohe",OneHotEncoder(handle_unknown="ignore",sparse_output=False))
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers = [
        ("num_pipeline",num_pipeline,num_col),
        ("cat_pipeline",cat_pipeline,cat_col)
    ]
)

# %%
TARGET_COLUMN='winner_enc'

# %%
input_data_train = train_data.drop(columns=[TARGET_COLUMN],axis=1)
output_data_train = train_data[TARGET_COLUMN]
input_data_test = test_data.drop(columns=[TARGET_COLUMN],axis=1)
output_data_test = test_data[TARGET_COLUMN]

# %%
input_data_train.shape,output_data_train.shape,input_data_test.shape,output_data_test.shape
# Out:
# ((931, 9), (931,), (71, 9), (71,))

# %%
input_data_train_arr = preprocessor.fit_transform(input_data_train)
input_data_test_arr = preprocessor.transform(input_data_test)

# %%
input_data_test_arr.shape
# Out:
# (71, 37)

# %%
def save_object(file_path,obj):
    dir_path = os.path.dirname(file_path)
    os.makedirs(dir_path,exist_ok=True)
        
    with open(file_path,"wb") as file_obj:
        pickle.dump(obj,file_obj)

# %%
save_object("Artifacts/preprocessor.pkl",preprocessor)

# %%
import numpy as np

# %%
def save_as_numpy_array(filepath:str,arr:np.array):

    os.makedirs(os.path.dirname(filepath),exist_ok=True)
    with open(filepath,"wb") as file:
        np.save(file,arr)

# %%
def load_object(filepath)-> object:

    with open(filepath,"rb") as file_obj:
        return pickle.load(file_obj)


def load_numpy_array(filepath)->np.array:
    
    with open(filepath,"rb") as file_obj:
        return np.load(file_obj)

# %%
print(input_data_train_arr.shape)
print(np.array(output_data_train).shape)
# Out:
# (931, 37)
# (931,)

# %%
output_data_train = np.array(output_data_train).reshape(-1, 1)
output_data_test = np.array(output_data_test).reshape(-1, 1)

# %%
print(input_data_train_arr.shape)
print(np.array(output_data_train).shape)
# Out:
# (931, 37)
# (931, 1)

# %%
print(input_data_train_arr.shape)
print(np.array(output_data_train).shape)
# Out:
# (931, 37)
# (931, 1)

# %%
input_data_train_arr.shape
# Out:
# (931, 37)

# %%
train_arr = np.c_[input_data_train_arr,output_data_train]
test_arr = np.c_[input_data_test_arr,output_data_test]

# %%
train_arr.shape
# Out:
# (931, 38)

# %%
save_as_numpy_array("Artifacts/train_arr.npy",train_arr)
save_as_numpy_array("Artifacts/test_arr.npy",test_arr)

# %%
train_arr = load_numpy_array("Artifacts/train_arr.npy")
test_arr = load_numpy_array("Artifacts/test_arr.npy")

# %%
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.metrics import f1_score,precision_score,recall_score

# %%
models = {
    "Random_Forest":RandomForestClassifier(verbose=1),
    "Decision_Tree":DecisionTreeClassifier(),
    "AdaBoostClassifier":AdaBoostClassifier(),
    "GradientBoostingClassifier":GradientBoostingClassifier(verbose=1),
    "KNeighborsClassifier":KNeighborsClassifier(),
    "XGBClassifier":XGBClassifier(verbose=1)
}

# %%
X_train = train_arr[:,:-1]
y_train = train_arr[:,-1]
X_test = test_arr[:,:-1]
y_test = test_arr[:,-1]

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((931, 37), (931,), (71, 37), (71,))

# %%
for model in models.keys():
    model_name = model
    model_obj = models[model]
    model_obj.fit(X_train,y_train)
    y_pred = model_obj.predict(X_test)
    print(f"f1 score macro for model {model_name} is {f1_score(y_pred,y_test,average='macro')}")
    print(f"f1 score for weighted model {model_name} is {f1_score(y_pred,y_test,average='weighted')}")
    print(f"recall score macro for model {model_name} is {recall_score(y_pred,y_test,average='macro')}")
    print(f"recall score for weighted model {model_name} is {recall_score(y_pred,y_test,average='weighted')}")
    print(f"precision score macro for model {model_name} is {precision_score(y_pred,y_test,average='macro')}")
    print(f"precision score weighted for model {model_name} is {precision_score(y_pred,y_test,average='weighted')}")
# Out:
# f1 score macro for model Random_Forest is 0.2529610740137056
# f1 score for weighted model Random_Forest is 0.2519254898795299
# recall score macro for model Random_Forest is 0.28787878787878785
# recall score for weighted model Random_Forest is 0.2535211267605634
# precision score macro for model Random_Forest is 0.2561976911976912
# precision score weighted for model Random_Forest is 0.27898197264394453
# f1 score macro for model Decision_Tree is 0.23061473614105193
# f1 score for weighted model Decision_Tree is 0.21586467646512122
# recall score macro for model Decision_Tree is 0.2772222222222222
# recall score for weighted model Decision_Tree is 0.22535211267605634
# precision score macro for model Decision_Tree is 0.2219119769119769
# precision score weighted for model Decision_Tree is 0.2376796130317257
# f1 score macro for model AdaBoostClassifier is 0.4204934685197843
# f1 score for weighted model AdaBoostClassifier is 0.4778093066640138
# recall score macro for model AdaBoostClassifier is 0.43662698412698414
# recall score for weighted model AdaBoostClassifier is 0.4647887323943662
# precision score macro for model AdaBoostClassifier is 0.46045454545454545
# precision score weighted for model AdaBoostClassifier is 0.5676290063614008
# f1 score macro for model GradientBoostingClassifier is 0.381344537815126
# f1 score for weighted model GradientBoostingClassifier is 0.3867834457726753
# recall score macro for model GradientBoostingClassifier is 0.4881601731601731
# recall score for weighted model GradientBoostingClassifier is 0.39436619718309857
# precision score macro for model GradientBoostingClassifier is 0.38350649350649346
# precision score weighted for model GradientBoostingClassifier is 0.4303721317805825
# f1 score macro for model KNeighborsClassifier is 0.30809829059829064
# f1 score for weighted model KNeighborsClassifier is 0.34350246779824245
# recall score macro for model KNeighborsClassifier is 0.3616666666666667
# recall score for weighted model KNeighborsClassifier is 0.3380281690140845
# precision score macro for model KNeighborsClassifier is 0.31945887445887444
# precision score weighted for model KNeighborsClassifier is 0.41634961282848615
# f1 score macro for model XGBClassifier is 0.3616450216450216
# f1 score for weighted model XGBClassifier is 0.3625022864459484
# recall score macro for model XGBClassifier is 0.4460805860805861
# recall score for weighted model XGBClassifier is 0.36619718309859156
# precision score macro for model XGBClassifier is 0.36076479076479073
# precision score weighted for model XGBClassifier is 0.40462166941040184

# %%
param_grids = {
    "Random_Forest": {
        'n_estimators': [100, 150,200,250,300],
        'max_depth': [10, 15,20,25,30],
        'min_samples_split': [2, 5,3,6]
    },
    "Decision_Tree": {
        'max_depth': [10, 15, 20,30, None],
        'criterion': ['gini', 'entropy']
    },
    "AdaBoostClassifier": {
        'n_estimators': [50, 75,100,150,200],
        'learning_rate': [0.01, 0.1,0.7,1.0,1.5]
    },
    "GradientBoostingClassifier": {
        'n_estimators': [150,250, 200],
        'learning_rate': [0.05,0.01,0.07],
        'max_depth': [3,4]
    },
    "KNeighborsClassifier": {
        'n_neighbors': [3, 5, 7],
        'weights': ['uniform', 'distance']
    },
    "XGBClassifier": {
        'n_estimators': [50,100,150,200,250,300],
        'max_depth': [3, 5,6,4],
        'learning_rate': [0.1, 0.2,0.01,0.07,0.3,0.4]
    }
}

# %%
best_models = {}

for name in models:
    print(f"\n🔍 Tuning {name}...")
    model = models[name]
    params = param_grids[name]

    grid_search = GridSearchCV(model, params, cv=5, scoring='f1_weighted', n_jobs=-1)
    grid_search.fit(X_train, y_train)

    best_model = grid_search.best_estimator_
    best_models[name] = best_model

    y_pred = best_model.predict(X_test)
    score = f1_score(y_test, y_pred, average='weighted')

    print(f"✅ Best F1 Score for {name}: {score:.4f}")
    print(f"🏆 Best Params: {grid_search.best_params_}")
# Out:
# 🔍 Tuning Random_Forest...
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# ✅ Best F1 Score for Random_Forest: 0.4941
# 🏆 Best Params: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 250}
#
# 🔍 Tuning Decision_Tree...
# ✅ Best F1 Score for Decision_Tree: 0.2457
# 🏆 Best Params: {'criterion': 'gini', 'max_depth': 10}
#
# 🔍 Tuning AdaBoostClassifier...
# ✅ Best F1 Score for AdaBoostClassifier: 0.4569
# 🏆 Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#
# 🔍 Tuning GradientBoostingClassifier...
#       Iter       Train Loss   Remaining Time
#          1           2.1900           12.48s
#          2           2.1757           11.02s
#          3           2.1626           10.19s
#          4           2.1504           10.32s
#          5           2.1389           10.84s
#          6           2.1280           10.54s
#          7           2.1176           10.15s
#          8           2.1078            9.87s
#          9           2.0983            9.69s
#         10           2.0893            9.56s
#         20           2.0158            8.26s
#         30           1.9629            7.60s
#         40           1.9223            7.08s
#         50           1.8895            6.62s
#         60           1.8627            6.14s
#         70           1.8404            5.68s
#         80           1.8212            5.21s
#         90           1.8041            4.81s
#        100           1.7888            4.41s
#        200           1.6737            0.00s
# ✅ Best F1 Score for GradientBoostingClassifier: 0.4749
# 🏆 Best Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
#
# 🔍 Tuning KNeighborsClassifier...
# ✅ Best F1 Score for KNeighborsClassifier: 0.3490
# 🏆 Best Params: {'n_neighbors': 7, 'weights': 'uniform'}
#
# 🔍 Tuning XGBClassifier...
# ✅ Best F1 Score for XGBClassifier: 0.4964
# 🏆 Best Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
